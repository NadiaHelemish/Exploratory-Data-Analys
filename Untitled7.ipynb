# %% [markdown]
# # Author : Nadia Helemish

# %% [markdown]
# GRIP @ The Sparks Foundation

# %% [markdown]
# Task-4---Exploratory-Data-Analysis---Terrorism

# %% [markdown]
# Problem Statement - ● Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’ ● As a security/defense analyst, try to find out the hot zone of terrorism. ● What all security issues and insights you can derive by EDA?

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the dataset

# %%
# Reading data from remote link
df = pd.read_excel("E:\SPARKS\Task 4\globalterrorismdb_0718dist.xlsx")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
#    Wound                  target1 summary                               Group  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    NaN             U.S. Embassy     NaN                             Unknown
# 4    NaN           U.S. Consulate     NaN                             Unknown
#
#                     Targettype      Weapon motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype     30116
# kill           46149
# Wound          50331
# target1        30788
# summary        66404
# Group          30337
# Targettype     30116
# Weapon         35234
# motive        138527
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181690 entries, 0 to 181689
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181690 non-null  int64
#  1   Month       181690 non-null  int64
#  2   day         181690 non-null  int64
#  3   Country     181690 non-null  object
#  4   State       181269 non-null  object
#  5   Region      181690 non-null  object
#  6   City        181256 non-null  object
#  7   latitude    177134 non-null  float64
#  8   longitude   177133 non-null  float64
#  9   Attacktype  151574 non-null  object
#  10  kill        135541 non-null  float64
#  11  Wound       131359 non-null  float64
#  12  target1     150902 non-null  object
#  13  summary     115286 non-null  object
#  14  Group       151353 non-null  object
#  15  Targettype  151574 non-null  object
#  16  Weapon      146456 non-null  object
#  17  motive      43163 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 25.0+ MB

# %%
df.describe()
# Out:
#                 Year          Month            day       latitude  \
# count  181690.000000  181690.000000  181690.000000  177134.000000
# mean     2002.638956       6.467263      15.505614      23.498300
# std        13.259456       3.388308       8.814060      18.569286
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude           kill          Wound
# count  1.771330e+05  135541.000000  131359.000000
# mean  -4.586985e+02       2.185781       3.139861
# std    2.047796e+05      10.723777      39.452153
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545026e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# 75%    6.871033e+01       2.000000       2.000000
# max    1.793667e+02    1570.000000    8191.000000

# %%
df.shape
# Out:
# (181690, 18)

# %%
df.tail()
# Out:
#         Year  Month  day      Country            State  \
# 181685  2017     12   31      Somalia  Middle Shebelle
# 181686  2017     12   31        Syria         Lattakia
# 181687  2017     12   31  Philippines      Maguindanao
# 181688  2017     12   31        India          Manipur
# 181689  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   latitude   longitude  \
# 181685          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181686  Middle East & North Africa         Jableh  35.407278   35.942679
# 181687              Southeast Asia       Kubentog   6.900742  124.437908
# 181688                  South Asia         Imphal  24.798346   93.940430
# 181689              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                Attacktype  kill  Wound     target1  \
# 181685      Armed Assault   1.0    2.0  Checkpoint
# 181686                NaN   NaN    NaN         NaN
# 181687                NaN   NaN    NaN         NaN
# 181688  Bombing/Explosion   0.0    0.0      Office
# 181689  Bombing/Explosion   0.0    0.0     Unknown
#
#                                                   summary       Group  \
# 181685  12/31/2017: Assailants opened fire on a Somali...  Al-Shabaab
# 181686  12/31/2017: Assailants launched mortars at the...         NaN
# 181687  12/31/2017: Assailants set fire to houses in K...         NaN
# 181688  12/31/2017: Assailants threw a grenade at a Fo...     Unknown
# 181689  12/31/2017: An explosive device was discovered...     Unknown
#
#                   Targettype      Weapon motive
# 181685              Military    Firearms    NaN
# 181686                   NaN         NaN    NaN
# 181687                   NaN         NaN    NaN
# 181688  Government (General)  Explosives    NaN
# 181689               Unknown  Explosives    NaN

# %%
# checking for duplicate values
df.duplicated().sum()
# Out:
# 9745

# %%
# dropping the duplicates
df.drop_duplicates()
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
#    Wound                  target1 summary                               Group  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    NaN             U.S. Embassy     NaN                             Unknown
# 4    NaN           U.S. Consulate     NaN                             Unknown
#
#                     Targettype      Weapon motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
df.tail()
# Out:
#         Year  Month  day      Country            State  \
# 181685  2017     12   31      Somalia  Middle Shebelle
# 181686  2017     12   31        Syria         Lattakia
# 181687  2017     12   31  Philippines      Maguindanao
# 181688  2017     12   31        India          Manipur
# 181689  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   latitude   longitude  \
# 181685          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181686  Middle East & North Africa         Jableh  35.407278   35.942679
# 181687              Southeast Asia       Kubentog   6.900742  124.437908
# 181688                  South Asia         Imphal  24.798346   93.940430
# 181689              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                Attacktype  kill  Wound     target1  \
# 181685      Armed Assault   1.0    2.0  Checkpoint
# 181686                NaN   NaN    NaN         NaN
# 181687                NaN   NaN    NaN         NaN
# 181688  Bombing/Explosion   0.0    0.0      Office
# 181689  Bombing/Explosion   0.0    0.0     Unknown
#
#                                                   summary       Group  \
# 181685  12/31/2017: Assailants opened fire on a Somali...  Al-Shabaab
# 181686  12/31/2017: Assailants launched mortars at the...         NaN
# 181687  12/31/2017: Assailants set fire to houses in K...         NaN
# 181688  12/31/2017: Assailants threw a grenade at a Fo...     Unknown
# 181689  12/31/2017: An explosive device was discovered...     Unknown
#
#                   Targettype      Weapon motive
# 181685              Military    Firearms    NaN
# 181686                   NaN         NaN    NaN
# 181687                   NaN         NaN    NaN
# 181688  Government (General)  Explosives    NaN
# 181689               Unknown  Explosives    NaN

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# number of attacks in years

year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           palette = "tab20")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
attack = df.Country.value_counts()[:10]
attack
# Out:
# Iraq              24635
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
df.Group.value_counts()[1:10]
# Out:
# Shining Path (SL)                                   4518
# Taliban                                             4422
# Farabundo Marti National Liberation Front (FMLN)    3350
# Irish Republican Army (IRA)                         2661
# Islamic State of Iraq and the Levant (ISIL)         2208
# Revolutionary Armed Forces of Colombia (FARC)       2060
# Basque Fatherland and Freedom (ETA)                 2006
# New People's Army (NPA)                             1657
# Liberation Tigers of Tamil Eelam (LTTE)             1582
# Name: Group, dtype: int64

# %%
plt.subplots(figsize=(20,10))
sns.barplot(df['Country'].value_counts()[:10].index,df['Country'].value_counts()[:10].values,palette='Blues')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %%
#people died due to accack

df = df[['Year','kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 296263
